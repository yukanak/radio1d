# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:80% !important; }</style>"))

import os,sys
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

parent_directory = os.path.dirname(os.getcwd())
sys.path.append(parent_directory)
import telescope_1d
from plot_random_sky_slices import plot_sky_slices_stat
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# <style>.container { width:80% !important; }</style>

# %%
npix = 2**12 
redundant = True
sky = 'uniform'
seed = 123
time_error = 100e-12
correlated = True
fig, rmap, rmapwe,t = plot_sky_slices_stat(npix, redundant, sky, seed, time_error, correlated, path = None, Ndishes_array=[128])
# Out:
# Creating map...
# Observing map...
# Generating real space maps...
# (256, 4097)

# %%
f=np.linspace(400,800,256)
plt.plot(np.var(rmap[:,2049-300:2049+300],axis=1))
plt.plot(np.var(rmapwe[:,2049-300:2049+300],axis=1))

# %%
plt.imshow(rmap,aspect='auto',origin='lower')

# %%
plt.plot(rmap[0,2049-300:2049+300])
#plt.plot(rmapwe[0,2049-100:2049+100])
#plt.plot(rmap[-1,2049-100:2049+100])

# %%
plt.plot(np.fft.rfft(np.abs(rmapwe[:,2046]**2)),label='we')
plt.plot(np.fft.rfft(np.abs(rmap[:,2046]**2)),label='nonwe')
plt.semilogy()
plt.legend()
# Out:
# /opt/conda/lib/python3.8/site-packages/numpy/core/_asarray.py:83: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# /opt/conda/lib/python3.8/site-packages/numpy/core/_asarray.py:83: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)

# %%
ps_binned_no_error
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-101-40247a6715fd> in <module>
# ----> 1 ps_binned_no_error
#
# NameError: name 'ps_binned_no_error' is not defined
